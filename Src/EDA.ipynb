# %% [markdown]
# # Demonstration of Data Manipulation
#
# [![Open In Colab](https://google.com)](https://google.com)
#
# This notebook illustrates how to do some exploratory data analysis with the help of AI.

# %% [markdown]
# **Prompt:**
# > Load the CSV file and display the first rows of the data.

# %% [markdown]
# **Prompt:**
#
#
# > Plot the signal and labels for the first 30 seconds of data

# %% [markdown]
# **Prompt:**
#
#
# > What type of exploratory data analysis could I do for this datasets?

# %% [markdown]
# **Prompt:**
# > Let's do some signal distribution analysis for all the data and broken down per label.

# %% [markdown]
# **Prompt:**
#
# > The histograms for the raw values of the signals seem to indicate that both labels are identifical. However, I can see that one of the signals has a higher frequency of the other. What analysis could I do to highlight this differences?
